# %%
import pandas as pd
# Out:
# C:\Users\sfarj\AppData\Local\Temp\ipykernel_19864\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
file_paths = {
    "economic": r"C:\Users\sfarj\OneDrive - California State University, Northridge\Graduate Project-Farjad-Desktop\Week_3\Week_3\Economic Indicators.csv",
    "environmental_1": r"C:\Users\sfarj\OneDrive - California State University, Northridge\Graduate Project-Farjad-Desktop\Week_3\Week_3\Environmental indicators..csv",
    "qpsd": r"C:\Users\sfarj\OneDrive - California State University, Northridge\Graduate Project-Farjad-Desktop\Week_3\Week_3\QPSD Indicator.csv",
    "social": r"C:\Users\sfarj\OneDrive - California State University, Northridge\Graduate Project-Farjad-Desktop\Week_3\Week_3\Social Indicators.csv",
    "statistical": r"C:\Users\sfarj\OneDrive - California State University, Northridge\Graduate Project-Farjad-Desktop\Week_3\Week_3\Statistical indicators.csv"
}

dfs = {}
for name, path in file_paths.items():
    dfs[name] = pd.read_csv(path, encoding='ISO-8859-1')

{key: df.head() if isinstance(df, pd.DataFrame) else df for key, df in dfs.items()}
# Out:
# {'economic':     Country Name Country Code                                 Series Name  \
#  0  United States          USA                     GDP (constant 2015 US$)
#  1  United States          USA                          GDP (constant LCU)
#  2  United States          USA                           GDP (current LCU)
#  3  United States          USA                           GDP (current US$)
#  4  United States          USA  GDP deflator (base year varies by country)
#
#        Series Code Series_type 2021 [YR2021] 2022 [YR2022] 2023 [YR2023]
#  0  NY.GDP.MKTP.KD         GDP      2.09E+13      2.14E+13      2.21E+13
#  1  NY.GDP.MKTP.KN         GDP      2.09E+13      2.14E+13      2.21E+13
#  2  NY.GDP.MKTP.CN         GDP      2.37E+13      2.60E+13      2.77E+13
#  3  NY.GDP.MKTP.CD         GDP      2.37E+13      2.60E+13      2.77E+13
#  4  NY.GDP.DEFL.ZS         GDP   113.2103304   121.2816392   125.6458273  ,
#  'environmental_1':     Country Name Country Code  \
# ...

# %%
combined_df = pd.concat(dfs.values(), axis=0, join='outer', ignore_index=True)

output_file_path = r'C:\Users\sfarj\OneDrive - California State University, Northridge\Graduate Project-Farjad-Desktop\Week 4/combined_concat_dataset.csv'

combined_df.to_csv(output_file_path, index=False, encoding='utf-8')
